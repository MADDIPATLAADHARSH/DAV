# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('iris')
#without regression
sns.pairplot(df,kind="scatter")
plt.show()

# %%
import seaborn as sb
from matplotlib import pyplot
df = sb.load_dataset('tips')
sb.regplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %%
import matplotlib.pyplot as plt
from scipy import stats

# %%
x = [5,7,8,7,2,17,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

# %%
print(f"Length of x: {len(x)}")
print(f"Length of y: {len(y)}")
# Out:
# Length of x: 15
# Length of y: 13

# %%
if len(x) > len(y):
    x = x[:len(y)]
else:
    y = y[:len(x)]

# %%
slope, intercept, r, p, std_err = stats.linregress(x, y)

# %%
def myfunc(x):
  return slope*x+intercept

# %%
mymodel = list(map(myfunc, x))

# %%
plt.scatter(x,y)

# %%
plt.plot(x,mymodel)

# %%
import numpy as np
def estimate_coef(p,q):
  n1=np.size(p)
  mp=np.mean(p)
  mq=np.mean(q)
  ss_pq=np.sum(q*p)-n1*mq*mp
  ss_pp=np.sum(p*p)-n1*mp*mp
  b1=ss_pq/ss_pp
  b0=mp-b1*mp
  return(b0,b1)

# %%
def plot_regression_line(p,q,b):
  plt.scatter(p,q,color="m",marker="o",s=30)

# %%
mtplt.xlabel('p')
mtplt.ylabel('q')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-72242937cd19> in <cell line: 1>()
# ----> 1 mtplt.xlabel('p')
#       2 mtplt.ylabel('q')
#
# NameError: name 'mtplt' is not defined
